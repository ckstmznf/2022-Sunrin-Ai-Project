# %% [markdown]
# # 프로젝트 개요
#
# [ 파일명 수정 ]
# - 조(학번_이름, 학번_이름)_주제명.ipynb
#
# [ 팀원 ]
# - 팀원 1 학번 : 20511
# - 팀원 1 이름 : 박희찬
# - 팀원 2 학번 : 20514
# - 팀원 2 이름 : 여준혁
#
# [ 주제 ]
# - 프로젝트 주제 : 인스타그램의 스팸/가짜 계정과 진짜 사람 계정을 구분하는 인공지능 구현하기
#
# [ 유의사항 ]
# - 각 단계마다 Markdown과 Code를 최대한 구체적으로 작성할 것
# - 아래의 양식은 가이드라인일 뿐, 머신러닝 과정의 6단계와 필수 조건이 모두 존재한다면 양식 및 순서 등을 자유롭게 수정하여 작성 가능함

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # 1. 문제 정의
#
# [ 내용 ]
# - 프로젝트 주제를 구체적으로 설명 (주제 / 선정 이유 / 계획 등)

# %% [markdown]
# [ 문제 정의 ]
# - 주제 (# 필수 조건)
#      - 인스타 스팸 계정 구분
# - 선정 이유 (# 필수 조건)
#
# > 인스타그램에서 새로운 사람이 날 팔로우하고, DM이 왔다.
# >
# > 셀레이는 마음으로 어떤 사람일지 보니까 DM 내용이 다음과 같았다.
#
#
# ```
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ```
#
#
#
# <img src="https://i.imgur.com/UgtZh1O.jpg" width="500"/>
#
#
# > 스팸 계정에 속았다는 분함에 이 프로젝트를 기획 했다.
#
# - 계획
#     - 플랜 A : 데이터를 직접 크롤링 해서 인스타에서 직접 데이터를 가져온다.
#     - 플랜 B : 케글에 있는 아주 좋고 깔끔하고 편리한 데이터를 가져온다
#
# - 크롤링은 성공 했지만, 학습이 잘 시켜지지 않았다. 플랜 A 실패

# %% [markdown]
# # 2. 데이터 수집
#
# [ 내용 ]
# - 프로젝트 진행을 위해 필요한 데이터 수집
# - 사이킷런에 내장되어 있는 학습용 데이터 사용 금지
# - 수집한 데이터의 소스(사이트 및 링크) 반드시 기재

# %% [markdown]
# [ 데이터 수집 ]
# - 데이터 파일명 (# 필수 조건) : user_info.csv
# - 데이터 소스 (# 필수 조건)
#     - profile pic : 계정의 프로필 사진 여부
#     - nums/length username : 계정 이름의 숫자, 문자의 비율
#     - fullname words : 계정 이름의 단어 수
#     - nums/length fullname : 계정 이름에서 숫자가 차지하는 비율
#     - name==username : 사용자 이름과 계정 이름이 같은지
#     - description length : 계정 설명의 길이
#     - external URL : 계정의 외부 링크가 있는지
#     - private : 계정이 비공개인지
#     - #posts : 게시물 수
#     - #followers : 팔로워 수
#     - #follows : 팔로우 수
#     - fake : 스팸 계정 여부
# - 데이터 출처 : https://www.kaggle.com/datasets/free4ever1/instagram-fake-spammer-genuine-accounts

# %%
# 데이터 수집

# %%
user_info = pd.read_csv("user_info.csv")

user_info
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                   0.0
# 1              1                  0.00               2                   0.0
# 2              1                  0.10               2                   0.0
# 3              1                  0.00               1                   0.0
# 4              1                  0.00               2                   0.0
# ..           ...                   ...             ...                   ...
# 691            1                  0.29               1                   0.0
# 692            1                  0.40               1                   0.0
# 693            1                  0.00               2                   0.0
# 694            0                  0.17               1                   0.0
# 695            1                  0.44               1                   0.0
#
# ...

# %% [markdown]
# # 3. 데이터 전처리
#
# [ 내용 ]
# - 데이터 분석 및 모델 학습을 위한 구조로 데이터를 가공하거나 변형
# - 기본적으로 코드(판다스 및 넘파이 라이브러리 등 활용)를 통해 전처리 작업을 수행해야 하지만, 힘들 경우 데이터 파일 자체를 수정하여 전처리하여도 됨
# - (# 필수 조건 : 위의 경우, 수행해야 하는 전처리 작업과 수행하지 못한 이유를 작성해야 함)
# - 모든 전처리 작업이 수행된 최종 데이터를 명시해야 함

# %% [markdown]
# [ 데이터 전처리 ]
# - 필요한 전처리 작업 :
# - 전처리 결과 :
# -

# %%
# 데이터 전처리

# %%
print("데이터가 너무 깔끔해서 불필요")
# Out:
# 데이터가 너무 깔끔해서 불필요

# %% [markdown]
# # 4. 데이터 분석
#
# [ 내용 ]
# - 수집한 데이터의 탐색 및 분석을 진행
# - 반드시 하나 이상의 그래프(맷플롯립 라이브러리 등 활용)를 활용해야 함 (# 필수 조건)
# - 매 데이터 분석의 결과를 명시해야 함 (# 필수 조건)

# %% [markdown]
# [ 데이터 분석 ]
# - 분석 내용 :
# - 분석 결과 :
# -

# %%
plt.rc("font", family="Malgun Gothic")
plt.rcParams["axes.unicode_minus"] = False

# %%
lables = ["같다", "다르다"]

plt.title("사용자의 이름과 계정 이름이 같은 계정의 비율")

same = len(user_info[user_info["name==username"] == 1])
diff = len(user_info[user_info["name==username"] == 0])

plt.pie([same, diff], labels=lables, autopct='%1.1f%%')

plt.legend(lables)

plt.show()

# %%
lables = ["같은데 스팸이 아니다.", "다른데 스팸이 아니다", "같은데 스팸이다", "다른데 스팸이다"]

same = len(user_info[(user_info["name==username"] == 1) & (user_info["fake"] == 0)])
diff = len(user_info[(user_info["name==username"] == 0) & (user_info["fake"] == 0)])
sameFake = len(user_info[(user_info["name==username"] == 1) & (user_info["fake"] == 1)])
diffFake = len(user_info[(user_info["name==username"] == 0) & (user_info["fake"] == 1)])


plt.title("사용자의 이름과 계정 이름이 같은 계정의 비율")

plt.pie([same, diff, sameFake, diffFake], labels=lables, autopct='%1.1f%%')

plt.legend(lables)

plt.show()

# %%
user_info.info()
user_info.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   profile pic           696 non-null    int64
#  1   nums/length username  696 non-null    float64
#  2   fullname words        696 non-null    int64
#  3   nums/length fullname  696 non-null    float64
#  4   name==username        696 non-null    int64
#  5   description length    696 non-null    int64
#  6   external URL          696 non-null    int64
#  7   private               696 non-null    int64
#  8   #posts                696 non-null    int64
#  9   #followers            696 non-null    int64
#  10  #follows              696 non-null    int64
#  11  fake                  696 non-null    int64
# dtypes: float64(2), int64(10)
# memory usage: 65.4 KB
#        profile pic  nums/length username  fullname words  \
# ...

# %% [markdown]
# # 5. 모델 학습
#
# [ 내용 ]
# - 머신러닝 알고리즘(회귀 및 분류)을 사용하여 모델의 학습을 진행
# - 수업시간에 배운 것 이외의 알고리즘도 사용 가능함
# - (# 필수 조건 : 위의 경우, 해당 알고리즘의 원리 및 간단한 설명을 작성해야 함)
# - 반드시 '훈련 데이터'를 이용하여 모델의 학습을 진행해야 함 (# 필수 조건)

# %% [markdown]
# [ 모델 학습 ]
# - 사용한 머신러닝 알고리즘 (# 필수 조건) :
# - 해당 알고리즘의 원리 :
# -

# %%
# 모델 학습

# %%
data_input = user_info.drop(["fake"], axis=1).to_numpy()
data_target = user_info["fake"].to_numpy()

print(data_input[:5])
print(data_target[:5])
# Out:
# [[1.00e+00 2.70e-01 0.00e+00 0.00e+00 0.00e+00 5.30e+01 0.00e+00 0.00e+00
#   3.20e+01 1.00e+03 9.55e+02]
#  [1.00e+00 0.00e+00 2.00e+00 0.00e+00 0.00e+00 4.40e+01 0.00e+00 0.00e+00
#   2.86e+02 2.74e+03 5.33e+02]
#  [1.00e+00 1.00e-01 2.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 1.00e+00
#   1.30e+01 1.59e+02 9.80e+01]
#  [1.00e+00 0.00e+00 1.00e+00 0.00e+00 0.00e+00 8.20e+01 0.00e+00 0.00e+00
#   6.79e+02 4.14e+02 6.51e+02]
#  [1.00e+00 0.00e+00 2.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 1.00e+00
#   6.00e+00 1.51e+02 1.26e+02]]
# [0 0 0 0 0]

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = train_test_split(data_input, data_target, test_size=0.15, stratify=data_target, random_state=1)

print(train_input.shape, train_target.shape)
print(test_input.shape, test_target.shape)
# Out:
# (591, 11) (591,)
# (105, 11) (105,)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

model_dtc_demo = DecisionTreeClassifier(random_state=1)
model_dtc_demo.fit(train_input, train_target)

plt.figure(figsize=(25, 10))
plot_tree(model_dtc_demo, filled=True)
plt.show()

print("모델의 깊이:", model_dtc_demo.get_depth())
# Out:
# 모델의 깊이: 11

# %%
# 모델의 최적의 깊이 찾아내기
# 깊이를 하나씩 줄여가면서 과대/과소 적합 평가

train_scores, test_scores = [], []
tree_range = range(model_dtc_demo.get_depth(), 0, -1)
for depth in tree_range:
    model_dtc_test = DecisionTreeClassifier(max_depth=depth, random_state=1)
    model_dtc_test.fit(train_input, train_target)
    
    train_score = model_dtc_test.score(train_input, train_target)
    test_score = model_dtc_test.score(test_input, test_target)
    train_scores.append(train_score)
    test_scores.append(test_score)

plt.figure(figsize=(10, 5))
plt.plot(tree_range, train_scores, "o--", markersize=10, label="train score")
plt.plot(tree_range, test_scores, "o--", markersize=10, label="test score")
plt.legend()
plt.xlabel("max_depth")
plt.ylabel("score")
plt.show()

# %%
model_dtc = DecisionTreeClassifier(max_depth=3, random_state=1)
model_dtc.fit(train_input, train_target)

plt.figure(figsize=(25, 7))
plot_tree(model_dtc, filled=True, feature_names=["profile pic", "nums/length username", "fullname words", "nums/length fullname", "name==username", "description length", "external URL", "private", "posts", "followers", "follows"])
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

model_knc = KNeighborsClassifier()
model_knc.fit(train_input, train_target)
# Out:
# KNeighborsClassifier()

# %%
print(f"예측한 값 : {model_knc.predict([test_input[10]])}")
print(f"실제 값 : {test_target[10]}")
# Out:
# 예측한 값 : [0]
# 실제 값 : 0

# %%
test_predict = model_knc.predict(test_input)
test_result = test_predict == test_target

plt.title("K 최근접 이웃 분류 알고리즘을 사용해서 예측한 ")

plt.pie(
    [test_result.sum(), len(test_result) - test_result.sum()],
    autopct='%1.1f%%',
    labels=["예측 성공", "예측 실패"],
    explode = (0, 0.1),
    colors=["skyblue", "pink"]
)

plt.legend()

plt.show()

# %% [markdown]
# # 6. 모델 평가
#
# [ 내용 ]
# - 학습이 완료된 모델을 통해 값을 예측해보고, 최종적으로 모델의 성능을 평가
# - 반드시 '테스트 데이터'를 이용하여 모델의 학습을 진행해야 함 (# 필수 조건)

# %% [markdown]
# [ 모델 평가 ]
# - 성능 평가 결과 :
# -

# %%
# 모델 평가

# %%
print("결정트리 알로리즘")

print("훈련 세트로 평가한 정확도:", model_dtc.score(train_input, train_target))
print("테스트 세트로 평가한 정확도:", model_dtc.score(test_input, test_target))
# Out:
# 결정트리 알로리즘
# 훈련 세트로 평가한 정확도: 0.9069373942470389
# 테스트 세트로 평가한 정확도: 0.9047619047619048

# %%
print("K최근접 이웃 분류 알고리즘")

print("훈련 세트로 평가한 정확도:", model_knc.score(train_input, train_target))
print("테스트 세트로 평가한 정확도:", model_knc.score(test_input, test_target))
# Out:
# K최근접 이웃 분류 알고리즘
# 훈련 세트로 평가한 정확도: 0.9255499153976311
# 테스트 세트로 평가한 정확도: 0.8761904761904762

# %% [markdown]
# # 프로젝트 마무리
#
# [ 결론 ]
# - 진행한 프로젝트 정리

# %% [markdown]
# - 요약 (# 필수 조건) : 인스타그램의 스팸/가짜 계정과 진짜 계정을 구분하는 모델을 만들었다.
#
# - 의의 (# 필수 조건) :
#   * 인스타그램에서 실제로 스팸 계정을 감지해내고 차단하는 시스템 AI가 어떻게 만들어지는지에 대한 원리를 알 수 있었다.
#   * 단순히 팔로잉 수나 게시글 수 같은 데이터 뿐만 아니라 위에 나온 것처럼 매우 다양하고 디테일한 데이터(정보)도 판단에 사용할 수 있다는 것을 알 수 있었다.
#
# - 느낀점 (# 필수 조건) :
#   * 여준혁: 이번 프로젝트를 계기로 머신러닝과 분류 알고리즘에 대해서 잘 이해하게 되었고, 이를 실생활에 어떻게 사용할 수 있을까에 대해서 고민하는 시간을 가질 수 있었다. 그냥 보이는 수치 데이터만 쓰는 것이 아니라, 데이터에 숨겨져 있는 정보와 인과관계를 찾아내고 이를 적용시키는 것이 매우 중요하다는 것을 깨달았다.
#   * 박희찬:
